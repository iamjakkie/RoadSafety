# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('combined_final_dataset.csv')
profile = ProfileReport(df, title="RoadSafety Profiling Report")
profile.to_file("RoadSafety-ProfilingReport.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
